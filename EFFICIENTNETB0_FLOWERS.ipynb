# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter
import pickle
import datetime

from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,Flatten,MaxPool2D,BatchNormalization,GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications import VGG16

from tensorflow.keras.applications.efficientnet import EfficientNetB0
from keras.models import load_model

# %%
ROOT_DIR = "/content/drive/MyDrive/CS331-BÁO CÁO"
TRAIN_PATH = os.path.join(ROOT_DIR, 'flowers_splited/train')
TEST_PATH = os.path.join(ROOT_DIR, 'flowers_splited/test')

# %%
# splitfolders.ratio(DATASET_PATH,output=os.path.join(ROOT_DIR, 'flowers_splited'),seed=42,ratio=(.9, .1))

# %% [markdown]
# # Image Data Generators

# %%
batch_size = 32
img_height = 224
img_width = 224
target_size = (img_height, img_width)

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        TRAIN_PATH,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical', 
        color_mode='rgb',
        subset='training')

validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH, 
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical', 
    color_mode='rgb',
    subset='validation') 


test_generator = test_datagen.flow_from_directory(
        TEST_PATH,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical', 
        color_mode='rgb',
        shuffle=False)
# Out:
# Found 3107 images belonging to 5 classes.
# Found 775 images belonging to 5 classes.
# Found 435 images belonging to 5 classes.

# %%
counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}                     
class_weights
# Out:
# {0: 1.3763636363636365,
#  1: 1.0,
#  2: 1.3421985815602837,
#  3: 1.433712121212121,
#  4: 1.0692090395480225}

# %%
print(train_generator.class_indices)
print(counter)
print(class_weights)
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}
# Counter({1: 757, 4: 708, 2: 564, 0: 550, 3: 528})
# {0: 1.3763636363636365, 1: 1.0, 2: 1.3421985815602837, 3: 1.433712121212121, 4: 1.0692090395480225}

# %% [markdown]
# # Create Model

# %%
base_model = EfficientNetB0(include_top=False, weights="imagenet", input_shape=(img_height, img_width, 3))


for i, layer in enumerate(base_model.layers):
    print(i, layer.name, "-", layer.trainable)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# 0 input_1 - True
# 1 rescaling - True
# 2 normalization - True
# 3 tf.math.truediv - True
# 4 stem_conv_pad - True
# 5 stem_conv - True
# 6 stem_bn - True
# 7 stem_activation - True
# 8 block1a_dwconv - True
# 9 block1a_bn - True
# 10 block1a_activation - True
# 11 block1a_se_squeeze - True
# 12 block1a_se_reshape - True
# 13 block1a_se_reduce - True
# 14 block1a_se_expand - True
# 15 block1a_se_excite - True
# 16 block1a_project_conv - True
# 17 block1a_project_bn - True
# 18 block2a_expand_conv - True
# 19 block2a_expand_bn - True
# 20 block2a_expand_activation - True
# 21 block2a_dwconv_pad - True
# 22 block2a_dwconv - True
# 23 block2a_bn - True
# 24 block2a_activation - True
# 25 block2a_se_squeeze - True
# 26 block2a_se_reshape - True
# 27 block2a_se_reduce - True
# 28 block2a_se_expand - True
# 29 block2a_se_excite - True
# 30 block2a_project_conv - True
# 31 block2a_project_bn - True
# 32 block2b_expand_conv - True
# 33 block2b_expand_bn - True
# 34 block2b_expand_activation - True
# 35 block2b_dwconv - True
# 36 block2b_bn - True
# 37 block2b_activation - True
# 38 block2b_se_squeeze - True
# 39 block2b_se_reshape - True
# 40 block2b_se_reduce - True
# 41 block2b_se_expand - True
# 42 block2b_se_excite - True
# 43 block2b_project_conv - True
# 44 block2b_project_bn - True
# 45 block2b_drop - True
# 46 block2b_add - True
# 47 block3a_expand_conv - True
# 48 block3a_expand_bn - True
# 49 block3a_expand_activation - True
# 50 block3a_dwconv_pad - True
# 51 block3a_dwconv - True
# 52 block3a_bn - True
# 53 block3a_activation - True
# 54 block3a_se_squeeze - True
# 55 block3a_se_reshape - True
# 56 block3a_se_reduce - True
# 57 block3a_se_expand - True
# 58 block3a_se_excite - True
# 59 block3a_project_conv - True
# 60 block3a_project_bn - True
# 61 block3b_expand_conv - True
# 62 block3b_expand_bn - True
# 63 block3b_expand_activation - True
# 64 block3b_dwconv - True
# 65 block3b_bn - True
# 66 block3b_activation - True
# 67 block3b_se_squeeze - True
# 68 block3b_se_reshape - True
# 69 block3b_se_reduce - True
# 70 block3b_se_expand - True
# 71 block3b_se_excite - True
# 72 block3b_project_conv - True
# 73 block3b_project_bn - True
# 74 block3b_drop - True
# 75 block3b_add - True
# 76 block4a_expand_conv - True
# 77 block4a_expand_bn - True
# 78 block4a_expand_activation - True
# 79 block4a_dwconv_pad - True
# 80 block4a_dwconv - True
# 81 block4a_bn - True
# 82 block4a_activation - True
# 83 block4a_se_squeeze - True
# 84 block4a_se_reshape - True
# 85 block4a_se_reduce - True
# 86 block4a_se_expand - True
# 87 block4a_se_excite - True
# 88 block4a_project_conv - True
# 89 block4a_project_bn - True
# 90 block4b_expand_conv - True
# 91 block4b_expand_bn - True
# 92 block4b_expand_activation - True
# 93 block4b_dwconv - True
# 94 block4b_bn - True
# 95 block4b_activation - True
# 96 block4b_se_squeeze - True
# 97 block4b_se_reshape - True
# 98 block4b_se_reduce - True
# 99 block4b_se_expand - True
# 100 block4b_se_excite - True
# 101 block4b_project_conv - True
# 102 block4b_project_bn - True
# 103 block4b_drop - True
# 104 block4b_add - True
# 105 block4c_expand_conv - True
# 106 block4c_expand_bn - True
# 107 block4c_expand_activation - True
# 108 block4c_dwconv - True
# 109 block4c_bn - True
# 110 block4c_activation - True
# 111 block4c_se_squeeze - True
# 112 block4c_se_reshape - True
# 113 block4c_se_reduce - True
# 114 block4c_se_expand - True
# 115 block4c_se_excite - True
# 116 block4c_project_conv - True
# 117 block4c_project_bn - True
# 118 block4c_drop - True
# 119 block4c_add - True
# 120 block5a_expand_conv - True
# 121 block5a_expand_bn - True
# 122 block5a_expand_activation - True
# 123 block5a_dwconv - True
# 124 block5a_bn - True
# 125 block5a_activation - True
# 126 block5a_se_squeeze - True
# 127 block5a_se_reshape - True
# 128 block5a_se_reduce - True
# 129 block5a_se_expand - True
# 130 block5a_se_excite - True
# 131 block5a_project_conv - True
# 132 block5a_project_bn - True
# 133 block5b_expand_conv - True
# 134 block5b_expand_bn - True
# 135 block5b_expand_activation - True
# 136 block5b_dwconv - True
# 137 block5b_bn - True
# 138 block5b_activation - True
# 139 block5b_se_squeeze - True
# 140 block5b_se_reshape - True
# 141 block5b_se_reduce - True
# 142 block5b_se_expand - True
# 143 block5b_se_excite - True
# 144 block5b_project_conv - True
# 145 block5b_project_bn - True
# 146 block5b_drop - True
# 147 block5b_add - True
# 148 block5c_expand_conv - True
# 149 block5c_expand_bn - True
# 150 block5c_expand_activation - True
# 151 block5c_dwconv - True
# 152 block5c_bn - True
# 153 block5c_activation - True
# 154 block5c_se_squeeze - True
# 155 block5c_se_reshape - True
# 156 block5c_se_reduce - True
# 157 block5c_se_expand - True
# 158 block5c_se_excite - True
# 159 block5c_project_conv - True
# 160 block5c_project_bn - True
# 161 block5c_drop - True
# 162 block5c_add - True
# 163 block6a_expand_conv - True
# 164 block6a_expand_bn - True
# 165 block6a_expand_activation - True
# 166 block6a_dwconv_pad - True
# 167 block6a_dwconv - True
# 168 block6a_bn - True
# 169 block6a_activation - True
# 170 block6a_se_squeeze - True
# 171 block6a_se_reshape - True
# 172 block6a_se_reduce - True
# 173 block6a_se_expand - True
# 174 block6a_se_excite - True
# 175 block6a_project_conv - True
# 176 block6a_project_bn - True
# 177 block6b_expand_conv - True
# 178 block6b_expand_bn - True
# 179 block6b_expand_activation - True
# 180 block6b_dwconv - True
# 181 block6b_bn - True
# 182 block6b_activation - True
# 183 block6b_se_squeeze - True
# 184 block6b_se_reshape - True
# 185 block6b_se_reduce - True
# 186 block6b_se_expand - True
# 187 block6b_se_excite - True
# 188 block6b_project_conv - True
# 189 block6b_project_bn - True
# 190 block6b_drop - True
# 191 block6b_add - True
# 192 block6c_expand_conv - True
# 193 block6c_expand_bn - True
# 194 block6c_expand_activation - True
# 195 block6c_dwconv - True
# 196 block6c_bn - True
# 197 block6c_activation - True
# 198 block6c_se_squeeze - True
# 199 block6c_se_reshape - True
# 200 block6c_se_reduce - True
# 201 block6c_se_expand - True
# 202 block6c_se_excite - True
# 203 block6c_project_conv - True
# 204 block6c_project_bn - True
# 205 block6c_drop - True
# 206 block6c_add - True
# 207 block6d_expand_conv - True
# 208 block6d_expand_bn - True
# 209 block6d_expand_activation - True
# 210 block6d_dwconv - True
# 211 block6d_bn - True
# 212 block6d_activation - True
# 213 block6d_se_squeeze - True
# 214 block6d_se_reshape - True
# 215 block6d_se_reduce - True
# 216 block6d_se_expand - True
# 217 block6d_se_excite - True
# 218 block6d_project_conv - True
# 219 block6d_project_bn - True
# 220 block6d_drop - True
# 221 block6d_add - True
# 222 block7a_expand_conv - True
# 223 block7a_expand_bn - True
# 224 block7a_expand_activation - True
# 225 block7a_dwconv - True
# 226 block7a_bn - True
# 227 block7a_activation - True
# 228 block7a_se_squeeze - True
# 229 block7a_se_reshape - True
# 230 block7a_se_reduce - True
# 231 block7a_se_expand - True
# 232 block7a_se_excite - True
# 233 block7a_project_conv - True
# 234 block7a_project_bn - True
# 235 top_conv - True
# 236 top_bn - True
# 237 top_activation - True

# %%
model = tf.keras.Sequential([
    base_model, 
    tf.keras.layers.GlobalAveragePooling2D(), 
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(), 
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=1e-3), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 4,214,696
# Trainable params: 4,172,417
# Non-trainable params: 42,279
# _________________________________________________________________

# %% [markdown]
# # Callbacks

# %%
patience = 2
stop_patience = 3
factor = 0.5
callbacks = [
    ModelCheckpoint(os.path.join(ROOT_DIR, 'weights_model/effcientnetB0.h5'), save_best_only=True, save_weights_only=True, verbose=1),
    # EarlyStopping(patience=stop_patience, monitor='val_loss', verbose=1),
    ReduceLROnPlateau(monitor='val_accuracy', factor=factor, patience=patience, verbose=1, min_lr=1e-6)
]

# %% [markdown]
# # Model Training

# %%
epochs = 50
print(datetime.datetime.now())
history = model.fit(train_generator, validation_data=validation_generator, class_weight=class_weights, epochs=epochs, callbacks=callbacks, verbose=1)
print(datetime.datetime.now())
# Out:
# 2022-11-07 04:19:16.109613
# Epoch 1/50
# 98/98 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.7737
# Epoch 1: val_loss improved from inf to 1.74292, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 2276s 23s/step - loss: 0.8058 - accuracy: 0.7737 - val_loss: 1.7429 - val_accuracy: 0.2439 - lr: 0.0010
# Epoch 2/50
# 98/98 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.8677
# Epoch 2: val_loss did not improve from 1.74292
# 98/98 [==============================] - 59s 598ms/step - loss: 0.4856 - accuracy: 0.8677 - val_loss: 2.4361 - val_accuracy: 0.2439 - lr: 0.0010
# Epoch 3/50
# 98/98 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.9079
# Epoch 3: val_loss did not improve from 1.74292
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 98/98 [==============================] - 58s 592ms/step - loss: 0.3091 - accuracy: 0.9079 - val_loss: 8.7174 - val_accuracy: 0.1742 - lr: 0.0010
# Epoch 4/50
# 98/98 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9253
# Epoch 4: val_loss did not improve from 1.74292
# 98/98 [==============================] - 58s 595ms/step - loss: 0.2708 - accuracy: 0.9253 - val_loss: 3.0594 - val_accuracy: 0.2413 - lr: 5.0000e-04
# Epoch 5/50
# 98/98 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9601
# Epoch 5: val_loss did not improve from 1.74292
# 98/98 [==============================] - 59s 596ms/step - loss: 0.1384 - accuracy: 0.9601 - val_loss: 1.7736 - val_accuracy: 0.4555 - lr: 5.0000e-04
# Epoch 6/50
# 98/98 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9665
# Epoch 6: val_loss did not improve from 1.74292
# 98/98 [==============================] - 59s 596ms/step - loss: 0.1087 - accuracy: 0.9665 - val_loss: 1.8172 - val_accuracy: 0.2942 - lr: 5.0000e-04
# Epoch 7/50
# 98/98 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9733
# Epoch 7: val_loss did not improve from 1.74292
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 98/98 [==============================] - 59s 598ms/step - loss: 0.1097 - accuracy: 0.9733 - val_loss: 2.7931 - val_accuracy: 0.2271 - lr: 5.0000e-04
# Epoch 8/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9817
# Epoch 8: val_loss did not improve from 1.74292
# 98/98 [==============================] - 59s 597ms/step - loss: 0.0852 - accuracy: 0.9817 - val_loss: 3.2587 - val_accuracy: 0.2568 - lr: 2.5000e-04
# Epoch 9/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9710
# Epoch 9: val_loss improved from 1.74292 to 0.95439, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 603ms/step - loss: 0.0992 - accuracy: 0.9710 - val_loss: 0.9544 - val_accuracy: 0.7058 - lr: 2.5000e-04
# Epoch 10/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9842
# Epoch 10: val_loss improved from 0.95439 to 0.70946, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 604ms/step - loss: 0.0536 - accuracy: 0.9842 - val_loss: 0.7095 - val_accuracy: 0.7781 - lr: 2.5000e-04
# Epoch 11/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9887
# Epoch 11: val_loss did not improve from 0.70946
# 98/98 [==============================] - 59s 596ms/step - loss: 0.0496 - accuracy: 0.9887 - val_loss: 13.1779 - val_accuracy: 0.3432 - lr: 2.5000e-04
# Epoch 12/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9926
# Epoch 12: val_loss improved from 0.70946 to 0.66537, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 60s 609ms/step - loss: 0.0349 - accuracy: 0.9926 - val_loss: 0.6654 - val_accuracy: 0.8116 - lr: 2.5000e-04
# Epoch 13/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9771
# Epoch 13: val_loss did not improve from 0.66537
# 98/98 [==============================] - 58s 593ms/step - loss: 0.0908 - accuracy: 0.9771 - val_loss: 2.4436 - val_accuracy: 0.3806 - lr: 2.5000e-04
# Epoch 14/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9868
# Epoch 14: val_loss did not improve from 0.66537
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 98/98 [==============================] - 58s 591ms/step - loss: 0.0444 - accuracy: 0.9868 - val_loss: 2.1575 - val_accuracy: 0.4529 - lr: 2.5000e-04
# Epoch 15/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9920
# Epoch 15: val_loss improved from 0.66537 to 0.63922, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 603ms/step - loss: 0.0403 - accuracy: 0.9920 - val_loss: 0.6392 - val_accuracy: 0.8232 - lr: 1.2500e-04
# Epoch 16/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9955
# Epoch 16: val_loss did not improve from 0.63922
# 98/98 [==============================] - 58s 594ms/step - loss: 0.0301 - accuracy: 0.9955 - val_loss: 12.6867 - val_accuracy: 0.3794 - lr: 1.2500e-04
# Epoch 17/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9916
# Epoch 17: val_loss did not improve from 0.63922
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 98/98 [==============================] - 58s 592ms/step - loss: 0.0411 - accuracy: 0.9916 - val_loss: 2.3793 - val_accuracy: 0.4735 - lr: 1.2500e-04
# Epoch 18/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9920
# Epoch 18: val_loss improved from 0.63922 to 0.38250, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 605ms/step - loss: 0.0350 - accuracy: 0.9920 - val_loss: 0.3825 - val_accuracy: 0.8826 - lr: 6.2500e-05
# Epoch 19/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9932
# Epoch 19: val_loss did not improve from 0.38250
# 98/98 [==============================] - 58s 588ms/step - loss: 0.0320 - accuracy: 0.9932 - val_loss: 0.5916 - val_accuracy: 0.8413 - lr: 6.2500e-05
# Epoch 20/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9926
# Epoch 20: val_loss did not improve from 0.38250
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 98/98 [==============================] - 58s 593ms/step - loss: 0.0321 - accuracy: 0.9926 - val_loss: 0.6129 - val_accuracy: 0.8426 - lr: 6.2500e-05
# Epoch 21/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9926
# Epoch 21: val_loss improved from 0.38250 to 0.36930, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 602ms/step - loss: 0.0329 - accuracy: 0.9926 - val_loss: 0.3693 - val_accuracy: 0.8994 - lr: 3.1250e-05
# Epoch 22/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9952
# Epoch 22: val_loss improved from 0.36930 to 0.27907, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 599ms/step - loss: 0.0263 - accuracy: 0.9952 - val_loss: 0.2791 - val_accuracy: 0.9239 - lr: 3.1250e-05
# Epoch 23/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9961
# Epoch 23: val_loss did not improve from 0.27907
# 98/98 [==============================] - 58s 593ms/step - loss: 0.0229 - accuracy: 0.9961 - val_loss: 0.3266 - val_accuracy: 0.9097 - lr: 3.1250e-05
# Epoch 24/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9955
# Epoch 24: val_loss improved from 0.27907 to 0.24142, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 602ms/step - loss: 0.0207 - accuracy: 0.9955 - val_loss: 0.2414 - val_accuracy: 0.9277 - lr: 3.1250e-05
# Epoch 25/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9952
# Epoch 25: val_loss did not improve from 0.24142
# 98/98 [==============================] - 58s 595ms/step - loss: 0.0260 - accuracy: 0.9952 - val_loss: 0.4415 - val_accuracy: 0.8826 - lr: 3.1250e-05
# Epoch 26/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9929
# Epoch 26: val_loss did not improve from 0.24142
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 98/98 [==============================] - 58s 594ms/step - loss: 0.0332 - accuracy: 0.9929 - val_loss: 0.3506 - val_accuracy: 0.9058 - lr: 3.1250e-05
# Epoch 27/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9939
# Epoch 27: val_loss did not improve from 0.24142
# 98/98 [==============================] - 58s 591ms/step - loss: 0.0259 - accuracy: 0.9939 - val_loss: 0.2848 - val_accuracy: 0.9174 - lr: 1.5625e-05
# Epoch 28/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9961
# Epoch 28: val_loss did not improve from 0.24142
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 98/98 [==============================] - 59s 597ms/step - loss: 0.0183 - accuracy: 0.9961 - val_loss: 0.2490 - val_accuracy: 0.9252 - lr: 1.5625e-05
# Epoch 29/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9961
# Epoch 29: val_loss did not improve from 0.24142
# 98/98 [==============================] - 58s 590ms/step - loss: 0.0238 - accuracy: 0.9961 - val_loss: 0.2461 - val_accuracy: 0.9406 - lr: 7.8125e-06
# Epoch 30/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9958
# Epoch 30: val_loss did not improve from 0.24142
# 98/98 [==============================] - 58s 594ms/step - loss: 0.0209 - accuracy: 0.9958 - val_loss: 0.2602 - val_accuracy: 0.9368 - lr: 7.8125e-06
# Epoch 31/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9949
# Epoch 31: val_loss did not improve from 0.24142
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 98/98 [==============================] - 58s 588ms/step - loss: 0.0264 - accuracy: 0.9949 - val_loss: 0.2637 - val_accuracy: 0.9252 - lr: 7.8125e-06
# Epoch 32/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9945
# Epoch 32: val_loss improved from 0.24142 to 0.23337, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 602ms/step - loss: 0.0247 - accuracy: 0.9945 - val_loss: 0.2334 - val_accuracy: 0.9290 - lr: 3.9063e-06
# Epoch 33/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9952
# Epoch 33: val_loss improved from 0.23337 to 0.22660, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 98/98 [==============================] - 59s 602ms/step - loss: 0.0255 - accuracy: 0.9952 - val_loss: 0.2266 - val_accuracy: 0.9329 - lr: 3.9063e-06
# Epoch 34/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9968
# Epoch 34: val_loss did not improve from 0.22660
# 98/98 [==============================] - 58s 594ms/step - loss: 0.0185 - accuracy: 0.9968 - val_loss: 0.2608 - val_accuracy: 0.9355 - lr: 1.9531e-06
# Epoch 35/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9949
# Epoch 35: val_loss did not improve from 0.22660
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-06.
# 98/98 [==============================] - 58s 590ms/step - loss: 0.0176 - accuracy: 0.9949 - val_loss: 0.2450 - val_accuracy: 0.9329 - lr: 1.9531e-06
# Epoch 36/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9949
# Epoch 36: val_loss did not improve from 0.22660
# 98/98 [==============================] - 58s 590ms/step - loss: 0.0199 - accuracy: 0.9949 - val_loss: 0.2407 - val_accuracy: 0.9329 - lr: 1.0000e-06
# Epoch 37/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9936
# Epoch 37: val_loss did not improve from 0.22660
# 98/98 [==============================] - 59s 597ms/step - loss: 0.0254 - accuracy: 0.9936 - val_loss: 0.2500 - val_accuracy: 0.9394 - lr: 1.0000e-06
# Epoch 38/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9958
# Epoch 38: val_loss did not improve from 0.22660
# 98/98 [==============================] - 58s 590ms/step - loss: 0.0178 - accuracy: 0.9958 - val_loss: 0.2612 - val_accuracy: 0.9265 - lr: 1.0000e-06
# Epoch 39/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9916
# Epoch 39: val_loss did not improve from 0.22660
# 98/98 [==============================] - 58s 592ms/step - loss: 0.0302 - accuracy: 0.9916 - val_loss: 0.2472 - val_accuracy: 0.9303 - lr: 1.0000e-06
# Epoch 40/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9952
# Epoch 40: val_loss did not improve from 0.22660
# 98/98 [==============================] - 58s 593ms/step - loss: 0.0206 - accuracy: 0.9952 - val_loss: 0.2665 - val_accuracy: 0.9329 - lr: 1.0000e-06
# Epoch 41/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9968
# Epoch 41: val_loss improved from 0.22660 to 0.21289, saving model to /content/drive/MyDrive/CS331-BÁO CÁO/model/effcientnetB0.h5
# 98/98 [==============================] - 59s 603ms/step - loss: 0.0199 - accuracy: 0.9968 - val_loss: 0.2129 - val_accuracy: 0.9406 - lr: 1.0000e-06
# Epoch 42/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9958
# Epoch 42: val_loss did not improve from 0.21289
# 98/98 [==============================] - 59s 597ms/step - loss: 0.0201 - accuracy: 0.9958 - val_loss: 0.2244 - val_accuracy: 0.9394 - lr: 1.0000e-06
# Epoch 43/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9984
# Epoch 43: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 594ms/step - loss: 0.0136 - accuracy: 0.9984 - val_loss: 0.2428 - val_accuracy: 0.9342 - lr: 1.0000e-06
# Epoch 44/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9952
# Epoch 44: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 593ms/step - loss: 0.0207 - accuracy: 0.9952 - val_loss: 0.2331 - val_accuracy: 0.9406 - lr: 1.0000e-06
# Epoch 45/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9942
# Epoch 45: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 590ms/step - loss: 0.0242 - accuracy: 0.9942 - val_loss: 0.2535 - val_accuracy: 0.9329 - lr: 1.0000e-06
# Epoch 46/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9932
# Epoch 46: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 592ms/step - loss: 0.0239 - accuracy: 0.9932 - val_loss: 0.2407 - val_accuracy: 0.9381 - lr: 1.0000e-06
# Epoch 47/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9965
# Epoch 47: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 590ms/step - loss: 0.0188 - accuracy: 0.9965 - val_loss: 0.2410 - val_accuracy: 0.9277 - lr: 1.0000e-06
# Epoch 48/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9961
# Epoch 48: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 593ms/step - loss: 0.0187 - accuracy: 0.9961 - val_loss: 0.2145 - val_accuracy: 0.9329 - lr: 1.0000e-06
# Epoch 49/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9961
# Epoch 49: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 593ms/step - loss: 0.0185 - accuracy: 0.9961 - val_loss: 0.2419 - val_accuracy: 0.9406 - lr: 1.0000e-06
# Epoch 50/50
# 98/98 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9961
# Epoch 50: val_loss did not improve from 0.21289
# 98/98 [==============================] - 58s 594ms/step - loss: 0.0193 - accuracy: 0.9961 - val_loss: 0.2273 - val_accuracy: 0.9394 - lr: 1.0000e-06
# 2022-11-07 05:55:26.311986

# %%
test_model = model
test_model.load_weights('/content/drive/MyDrive/CS331-BÁO CÁO/weights_model/effcientnetB0.h5')

# %%
#Save 
with open(os.path.join(ROOT_DIR, '50epochs_history_dict_effcientnetB0.pkl'), 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
test_model.evaluate(test_generator)
# Out:
# 14/14 [==============================] - 2s 139ms/step - loss: 0.2233 - accuracy: 0.9402
# [0.22326840460300446, 0.9402298927307129]

# %%
pickle_in = open(os.path.join(ROOT_DIR, '50epochs_history_dict_effcientnetB0.pkl'), "rb")
dict_log = pickle.load(pickle_in)

# %%
dict_log.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.figure(figsize=(15, 10))
# plt.grid()


plt.plot(dict_log['loss'], label='Train loss')
plt.plot(dict_log['val_loss'], label='Valid loss')
plt.title('Loss (EfficientnetB0)', fontsize=23)
plt.ylabel('Loss', fontsize=23)
plt.xlabel('Số lượng epoch', fontsize=23)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# plt.legend(['train', 'validation'], loc="upper left")

plt.legend(loc=0, numpoints=1, fontsize=23, ncol=1)
plt.ylim(0, 1)

# plt.savefig("/content/drive/MyDrive/COURSES/CS231/results/vgg19-1.png")
# Out:
# (0.0, 1.0)

# %%
plt.figure(figsize=(15, 10))
# plt.grid()


plt.plot(dict_log['accuracy'], label='Train accuracy')
plt.plot(dict_log['val_accuracy'], label='Valid accuracy')
plt.title('Accuracy (EfficientnetB0)', fontsize=23)
plt.ylabel('Accuracy', fontsize=23)
plt.xlabel('Số lượng epoch', fontsize=23)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# plt.legend(['train', 'validation'], loc="upper left")

plt.legend(loc=0, numpoints=1, fontsize=23, ncol=1)
plt.ylim(0.8, 1)

# plt.savefig("/content/drive/MyDrive/COURSES/CS231/results/vgg19-1.png")
# Out:
# (0.8, 1.0)

# %%
plt.plot(dict_log['accuracy'])
plt.plot(dict_log['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
# plt.savefig("/content/drive/MyDrive/COURSES/CS231/results/vgg19-2.png")
plt.show()

# %% [markdown]
# # Predictions on Test Set

# %%
best_model = model
best_model.load_weights('/content/drive/MyDrive/CS331-BÁO CÁO/weights_model/effcientnetB0.h5')

# %%
best_model.evaluate(test_generator)
# Out:
# 14/14 [==============================] - 106s 7s/step - loss: 0.2233 - accuracy: 0.9402
# [0.22326840460300446, 0.9402298927307129]

# %%
preds = best_model.predict(test_generator)
# Out:
# 14/14 [==============================] - 3s 139ms/step

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]

    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir, dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      

    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    

    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(error_list[i], pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
            
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig1=plt.figure()
        fig1.set_figheight(len(plot_class)/3)
        fig1.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    
    if len(classes)<= 30:
        # create a confusion matrix and a test report        
        y_true= np.array(labels)        
        y_pred=np.array(y_pred)        
        cm = confusion_matrix(y_true, y_pred )
        clr = classification_report(y_true, y_pred, target_names=classes)
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        fig2 = plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix (EFFCIENTNETB0)")
        # plt.savefig("/content/drive/MyDrive/COURSES/CS231/results/vgg19-4.png", dpi = 100)
        plt.show()    
        print("Classification Report:\n----------------------\n", clr)

        # fig1.savefig("/content/drive/MyDrive/COURSES/CS231/results/vgg19-3.png", dpi = 100)

# %%
save_dir = ''
subject = "kq"
print_code = 0
print_info(test_generator, preds, print_code, save_dir, subject)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#        daisy       0.99      0.91      0.95        77
#    dandelion       0.95      0.99      0.97       106
#         rose       0.89      0.96      0.93        79
#    sunflower       0.95      0.95      0.95        74
#        tulip       0.93      0.89      0.91        99
#
#     accuracy                           0.94       435
#    macro avg       0.94      0.94      0.94       435
# weighted avg       0.94      0.94      0.94       435
